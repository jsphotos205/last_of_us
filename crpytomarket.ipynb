# %%
import requests
from pprint import pprint as pp
import pandas as pd

# %%
# https://cryptingup.com/apidoc/#introduction
response = requests.get('https://cryptingup.com/api/assets/?ID=btc')
main_info = response.json()
# Out:
# {'assets': [{'asset_id': 'USDT',
#              'change_1h': -0.002999565559667105,
#              'change_24h': -0.010997523851546991,
#              'change_7d': 0.1535617876537711,
#              'circulating_supply': 68319442037.678535,
#              'created_at': '2021-09-21T01:53:50',
#              'description': 'Launched in 2014, Tether is a blockchain-enabled '
#                             'platform designed to facilitate the use of fiat '
#                             'currencies in a digital manner. Tether works to '
#                             'disrupt the conventional financial system via a '
#                             'more modern approach to money. Tether has made '
#                             'headway by giving customers the ability to '
#                             'transact with traditional currencies across the '
#                             'blockchain, without the inherent volatility and '
#                             'complexity typically associated with a digital '
#                             'currency. As the first blockchain-enabled '
#                             'platform to facilitate the digital use of '
#                             'traditional currencies (a familiar, stable '
#                             'accounting unit), Tether has democratised '
#                             'cross-border transactions across the blockchain.',
#              'ethereum_contract_address': '',
#              'fully_diluted_market_cap': 68327298774.54414,
#              'market_cap': 68327298774.54414,
#              'max_supply': 0,
#              'name': 'Tether',
#              'pegged': 'USD',
#              'price': 1.000115000015095,
#              'quote': {'AUD': {'fully_diluted_market_cap': 98839218454.57695,
#                                'market_cap': 98839218454.57695,
#                                'price': 1.446721687218502,
#                                'volume_24h': 19356987834.270226},
#                        'CAD': {'fully_diluted_market_cap': 91283252140.66849,
#                                'market_cap': 91283252140.66849,
#                                'price': 1.336124087347278,
#                                'volume_24h': 17877203288.202633},
#                        'EUR': {'fully_diluted_market_cap': 63971264684.78107,
#                                'market_cap': 63971264684.78107,
#                                'price': 0.9363551981220891,
#                                'volume_24h': 12528336540.978043},
#                        'GBP': {'fully_diluted_market_cap': 56652655520.6999,
#                                'market_cap': 56652655520.6999,
#                                'price': 0.8292318237823966,
#                                'volume_24h': 11095036776.289974},
#                        'JPY': {'fully_diluted_market_cap': 8980098400178.123,
#                                'market_cap': 8980098400178.123,
#                                'price': 131.44279479369212,
#                                'volume_24h': 1758691116752.2288},
#                        'NZD': {'fully_diluted_market_cap': 108343584668.04169,
#                                'market_cap': 108343584668.04169,
#                                'price': 1.5858382538939593,
#                                'volume_24h': 21218353231.96441},
#                        'USD': {'fully_diluted_market_cap': 68327298774.54414,
#                                'market_cap': 68327298774.54414,
#                                'price': 1.000115000015095,
#                                'volume_24h': 13381436152.646467}},
#              'status': 'recent',
#              'total_supply': 68319442037.678535,
#              'updated_at': '2023-02-11T01:22:15.499366',
#              'volume_24h': 13381436152.646467,
#              'website': ''},
#             {'asset_id': 'BTC',
#              'change_1h': 0.3760792679215792,
#              'change_24h': -0.6954589238826103,
#              'change_7d': -6.994883959207889,
#              'circulating_supply': 19287250,
#              'created_at': '2021-09-21T01:27:16',
#              'description': 'Bitcoin uses peer-to-peer technology to operate '
#                             'with no central authority or banks; managing '
#                             'transactions and the issuing of bitcoins is '
#                             'carried out collectively by the network.\r\n'
#                             'Bitcoin is open-source; its design is public, '
#                             'nobody owns or controls Bitcoin and everyone can '
#                             'take part. Through many of its unique properties, '
#                             'Bitcoin allows exciting uses that could not be '
#                             'covered by any previous payment system.',
#              'ethereum_contract_address': '',
#              'fully_diluted_market_cap': 455728226123.571,
#              'market_cap': 418559249014.37354,
#              'max_supply': 21000000,
#              'name': 'Bitcoin',
#              'pegged': '',
#              'price': 21701.344101122428,
#              'quote': {'AUD': {'fully_diluted_market_cap': 659236096049.5908,
#                                'market_cap': 605469113977.7367,
#                                'price': 31392.195049980517,
#                                'volume_24h': 17888438373.756046},
#                        'CAD': {'fully_diluted_market_cap': 608839443662.5386,
#                                'market_cap': 559182788560.9666,
#                                'price': 28992.354460120885,
#                                'volume_24h': 16520920096.356422},
#                        'EUR': {'fully_diluted_market_cap': 426674425896.3458,
#                                'market_cap': 391875062898.5379,
#                                'price': 20317.8298045879,
#                                'volume_24h': 11577853850.906805},
#                        'GBP': {'fully_diluted_market_cap': 377860894089.04114,
#                                'market_cap': 347042739500.8981,
#                                'price': 17993.37590900196,
#                                'volume_24h': 10253293711.11333},
#                        'JPY': {'fully_diluted_market_cap': 59895303747218.82,
#                                'market_cap': 55010271295168.87,
#                                'price': 2852157.321296134,
#                                'volume_24h': 1625265146098.622},
#                        'NZD': {'fully_diluted_market_cap': 722628152117.5938,
#                                'market_cap': 663690944139.5266,
#                                'price': 34410.86438655208,
#                                'volume_24h': 19608588248.97291},
#                        'USD': {'fully_diluted_market_cap': 455728226123.571,
#                                'market_cap': 418559249014.37354,
#                                'price': 21701.344101122428,
#                                'volume_24h': 12366231668.812334}},
#              'status': 'recent',
#              'total_supply': 19287250,
#              'updated_at': '2023-02-11T01:22:10.601991',
#              'volume_24h': 12366231668.812334,
#              'website': ''},
#             {'asset_id': 'BUSD',
#              'change_1h': -0.04999999999998339,
#              'change_24h': -0.04999999999998339,
#              'change_7d': -1.1107784138320721e-14,
#              'circulating_supply': 16148914858.72,
#              'created_at': '2021-09-21T01:27:16',
#              'description': 'Binance USD (BUSD) is a new USD-denominated '
#                             'stablecoin approved by the New York State '
#                             'Department of Financial Services (NYDFS) that '
#                             'will be launched in partnership with Paxos and '
#                             'Binance.\r\n'
#                             'These are digitised US Dollars and are always '
#                             'purchased and redeemed at 1 BUSD for 1 US '
#                             'dollar.\r\n'
#                             'Binance and Paxos don’t charge a fee for the '
#                             'purchase or redemption of Binance USD (BUSD) '
#                             'However bank charges/wire fees may apply.\r\n'
#                             'Supported on both ERC-20 and BEP-2; transfer your '
#                             'dollars anywhere in minutes, with low cost and on '
#                             'the blockchain.',
#              'ethereum_contract_address': '0x4fabb145d64652a948d72533023f6e7a623c7c53',
#              'fully_diluted_market_cap': 16140840401.290642,
#              'market_cap': 16140840401.290642,
#              'max_supply': 0,
#              'name': 'Binance USD',
#              'pegged': '',
#              'price': 0.9995000000000002,
#              'quote': {'AUD': {'fully_diluted_market_cap': 23348618766.969116,
#                                'market_cap': 23348618766.969116,
#                                'price': 1.4458320556666668,
#                                'volume_24h': 11236204048.695662},
#                        'CAD': {'fully_diluted_market_cap': 21563685825.997036,
#                                'market_cap': 21563685825.997036,
#                                'price': 1.3353024654999157,
#                                'volume_24h': 10377229437.042255},
#                        'EUR': {'fully_diluted_market_cap': 15111821952.054922,
#                                'market_cap': 15111821952.054922,
#                                'price': 0.9357794058772269,
#                                'volume_24h': 7272358022.353764},
#                        'GBP': {'fully_diluted_market_cap': 13382959482.800291,
#                                'market_cap': 13382959482.800291,
#                                'price': 0.8287219048389395,
#                                'volume_24h': 6440366559.794176},
#                        'JPY': {'fully_diluted_market_cap': 2121353217012.603,
#                                'market_cap': 2121353217012.603,
#                                'price': 131.36196676813407,
#                                'volume_24h': 1020872277011.5588},
#                        'NZD': {'fully_diluted_market_cap': 25593818868.807575,
#                                'market_cap': 25593818868.807575,
#                                'price': 1.584863075489408,
#                                'volume_24h': 12316675948.390993},
#                        'USD': {'fully_diluted_market_cap': 16140840401.290642,
#                                'market_cap': 16140840401.290642,
#                                'price': 0.9995000000000002,
#                                'volume_24h': 7767559103.877346}},
#              'status': 'recent',
#              'total_supply': 16148914858.72,
#              'updated_at': '2023-02-11T01:22:10.678256',
#              'volume_24h': 7767559103.877346,
#              'website': ''},
#             {'asset_id': 'ETH',
#              'change_1h': 0.42528545424457753,
#              'change_24h': -2.068545740411442,
#              'change_7d': -8.18488077948093,
#              'circulating_supply': 122373866.2178,
#              'created_at': '2021-09-21T01:53:50',
#              'description': 'Ethereum is a platform powered by blockchain '
#                             'technology that is best known for its native '
#                             'cryptocurrency, called Ether, or ETH, or simply '
#                             'Ethereum. The distributed nature of blockchain '
#                             'technology is what makes the Ethereum platform '
#                             'secure, and that security enables ETH to accrue '
#                             'value.\r\n'
#                             'The Ethereum platform supports Ether in addition '
#                             'to a network of decentralized apps, otherwise '
#                             'known as dApps. Smart contracts, which originated '
#                             'on the Ethereum platform, are a central component '
#                             'of how the platform operates. Many decentralized '
#                             'finance (DeFi) and other applications use smart '
#                             'contracts in conjunction with blockchain '
#                             'technology.',
#              'ethereum_contract_address': '',
#              'fully_diluted_market_cap': 185662570478.99072,
#              'market_cap': 185662570478.99072,
#              'max_supply': 0,
#              'name': 'Ethereum',
#              'pegged': '',
#              'price': 1517.175,
#              'quote': {'AUD': {'fully_diluted_market_cap': 268571181526.7599,
#                                'market_cap': 268571181526.7599,
#                                'price': 2194.67758785,
#                                'volume_24h': 2812282480.8038993},
#                        'CAD': {'fully_diluted_market_cap': 248039707965.63095,
#                                'market_cap': 248039707965.63095,
#                                'price': 2026.9009685791236,
#                                'volume_24h': 2597291791.6584287},
#                        'EUR': {'fully_diluted_market_cap': 173826122957.94763,
#                                'market_cap': 173826122957.94763,
#                                'price': 1420.4513457846738,
#                                'volume_24h': 1820180994.5569038},
#                        'GBP': {'fully_diluted_market_cap': 153939608869.07758,
#                                'market_cap': 153939608869.07758,
#                                'price': 1257.945128538287,
#                                'volume_24h': 1611943852.8857048},
#                        'JPY': {'fully_diluted_market_cap': 24401201013854.453,
#                                'market_cap': 24401201013854.453,
#                                'price': 199398.79132710732,
#                                'volume_24h': 255511666336.3964},
#                        'NZD': {'fully_diluted_market_cap': 294396950928.06616,
#                                'market_cap': 294396950928.06616,
#                                'price': 2405.7174953032936,
#                                'volume_24h': 3082711193.3250837},
#                        'USD': {'fully_diluted_market_cap': 185662570478.99072,
#                                'market_cap': 185662570478.99072,
#                                'price': 1517.175,
#                                'volume_24h': 1944123681.9634733}},
#              'status': 'recent',
#              'total_supply': 122373866.2178,
#              'updated_at': '2023-02-11T01:22:11.511573',
#              'volume_24h': 1944123681.9634733,
#              'website': ''},
#             {'asset_id': 'MATIC',
#              'change_1h': 0.43246191181447796,
#              'change_24h': -2.7480874855236244,
#              'change_7d': 0.2514317254272359,
#              'circulating_supply': 9005469069.28493,
#              'created_at': '2021-09-21T01:53:50',
#              'description': 'Polygon (MATIC) is an Ethereum token that powers '
#                             'the Polygon Network, a scaling solution for '
#                             'Ethereum. Polygon aims to provide faster and '
#                             'cheaper transactions on Ethereum using Layer 2 '
#                             'sidechains, which are blockchains that run '
#                             'alongside the Ethereum main chain. Users can '
#                             'deposit Ethereum tokens to a Polygon smart '
#                             'contract, interact with them within Polygon, and '
#                             'then later withdraw them back to the Ethereum '
#                             'main chain. The MATIC token is used to pay '
#                             'transaction fees and participate in '
#                             'proof-of-stake consensus.',
#              'ethereum_contract_address': '0x7d1afa7b718fb893db30a3abc0cfc608aacfebb0',
#              'fully_diluted_market_cap': 12274364833.731852,
#              'market_cap': 11053641285.529085,
#              'max_supply': 0,
#              'name': 'Matic Network',
#              'pegged': '',
#              'price': 1.2274364833731852,
#              'quote': {'AUD': {'fully_diluted_market_cap': 17755547913.51392,
#                                'market_cap': 15989703754.335619,
#                                'price': 1.7755547913513923,
#                                'volume_24h': 594264663.6021948},
#                        'CAD': {'fully_diluted_market_cap': 16398188719.287245,
#                                'market_cap': 14767338130.383835,
#                                'price': 1.6398188719287246,
#                                'volume_24h': 548834885.3225548},
#                        'EUR': {'fully_diluted_market_cap': 11491843753.50667,
#                                'market_cap': 10348944347.125954,
#                                'price': 1.149184375350667,
#                                'volume_24h': 384623256.66384286},
#                        'GBP': {'fully_diluted_market_cap': 10177123567.482092,
#                                'market_cap': 9164977150.125069,
#                                'price': 1.0177123567482094,
#                                'volume_24h': 340620573.5090042},
#                        'JPY': {'fully_diluted_market_cap': 1613191301039.1562,
#                                'market_cap': 1452754436434.7637,
#                                'price': 161.31913010391563,
#                                'volume_24h': 53992284017.79557},
#                        'NZD': {'fully_diluted_market_cap': 19462919059.59709,
#                                'market_cap': 17527271558.919773,
#                                'price': 1.9462919059597092,
#                                'volume_24h': 651409075.2933127},
#                        'USD': {'fully_diluted_market_cap': 12274364833.731852,
#                                'market_cap': 11053641285.529085,
#                                'price': 1.2274364833731852,
#                                'volume_24h': 410813641.14348537}},
#              'status': 'recent',
#              'total_supply': 10000000000,
#              'updated_at': '2023-02-11T01:22:13.004855',
#              'volume_24h': 410813641.14348537,
#              'website': ''},
#             {'asset_id': 'APT',
#              'change_1h': -0.5908419497784217,
#              'change_24h': 2.9845173364113564,
#              'change_7d': -19.35290593169561,
#              'circulating_supply': 0,
#              'created_at': '2022-10-18T12:15:41.309402',
#              'description': '',
#              'ethereum_contract_address': '',
#              'fully_diluted_market_cap': 0,
#              'market_cap': 0,
#              'max_supply': 0,
#              'name': 'Aptos',
#              'pegged': '',
#              'price': 13.46,
#              'quote': {'AUD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 19.470634786666665,
#                                'volume_24h': 391166063.57895887},
#                        'CAD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 17.982162266762245,
#                                'volume_24h': 361262573.38791597},
#                        'EUR': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 12.601891748981963,
#                                'volume_24h': 253172659.39747745},
#                        'GBP': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 11.160176927595922,
#                                'volume_24h': 224208533.79684693},
#                        'JPY': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 1769.016580989579,
#                                'volume_24h': 35539634941.20202},
#                        'NZD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 21.342928460317587,
#                                'volume_24h': 428780540.67281026},
#                        'USD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 13.46,
#                                'volume_24h': 270412098.7045724}},
#              'status': 'recent',
#              'total_supply': 0,
#              'updated_at': '2023-02-11T01:22:10.024879',
#              'volume_24h': 270412098.7045724,
#              'website': ''},
#             {'asset_id': 'SOL',
#              'change_1h': 1.0336721144867547,
#              'change_24h': -0.8763602830930455,
#              'change_7d': -16.461998741533197,
#              'circulating_supply': 375274729.3932468,
#              'created_at': '2021-09-21T01:53:50',
#              'description': 'Solana is the fastest blockchain in the world and '
#                             'the fastest growing ecosystem in crypto, with '
#                             'over 400 projects spanning DeFi, NFTs, Web3 and '
#                             'more.',
#              'ethereum_contract_address': '',
#              'fully_diluted_market_cap': 11035779236.013613,
#              'market_cap': 7660660566.361381,
#              'max_supply': 0,
#              'name': 'Solana',
#              'pegged': '',
#              'price': 20.413473027473287,
#              'quote': {'AUD': {'fully_diluted_market_cap': 15963865311.34475,
#                                'market_cap': 11081569399.126408,
#                                'price': 29.529218279747628,
#                                'volume_24h': 361406126.53298986},
#                        'CAD': {'fully_diluted_market_cap': 14743474960.04177,
#                                'market_cap': 10234416149.695177,
#                                'price': 27.271796761381793,
#                                'volume_24h': 333777695.62852675},
#                        'EUR': {'fully_diluted_market_cap': 10332221047.39275,
#                                'market_cap': 7172274530.682093,
#                                'price': 19.11206369338644,
#                                'volume_24h': 233911268.6303599},
#                        'GBP': {'fully_diluted_market_cap': 9150167073.38791,
#                                'market_cap': 6351733083.421262,
#                                'price': 16.925555029220583,
#                                'volume_24h': 207150735.4032081},
#                        'JPY': {'fully_diluted_market_cap': 1450406868696.032,
#                                'market_cap': 1006822850165.4014,
#                                'price': 2682.8954131637283,
#                                'volume_24h': 32835777431.657616},
#                        'NZD': {'fully_diluted_market_cap': 17498948494.65801,
#                                'market_cap': 12147171651.30958,
#                                'price': 32.36874401574926,
#                                'volume_24h': 396158892.00470275},
#                        'USD': {'fully_diluted_market_cap': 11035779236.013613,
#                                'market_cap': 7660660566.361381,
#                                'price': 20.413473027473287,
#                                'volume_24h': 249839130.38445118}},
#              'status': 'recent',
#              'total_supply': 540612526.8914902,
#              'updated_at': '2023-02-11T01:22:14.689289',
#              'volume_24h': 249839130.38445118,
#              'website': ''},
#             {'asset_id': 'SHIB',
#              'change_1h': 2.5826709297813855,
#              'change_24h': 6.324733665949167,
#              'change_7d': -6.999013139754768,
#              'circulating_supply': 589656232874918.6,
#              'created_at': '2021-09-21T01:53:50',
#              'description': 'A Decentralized Meme Token that Evolved into a '
#                             'Vibrant Ecosystem. Shiba Inu aspires to be an '
#                             'Ethereum-based alternative to Dogecoin.\r\n'
#                             'It claims to be the "DOGECOIN KILLER". Shiba Inu '
#                             'coin was created in August 2020 under the '
#                             'pseudonym "Ryoshi".',
#              'ethereum_contract_address': '0x95aD61b0a150d79219dCF64E1E6Cc01f0B64C4cE',
#              'fully_diluted_market_cap': 7721276508.445211,
#              'market_cap': 7721276508.445211,
#              'max_supply': 0,
#              'name': 'Shiba Inu',
#              'pegged': '',
#              'price': 1.309453894992253e-05,
#              'quote': {'AUD': {'fully_diluted_market_cap': 11169253713.432798,
#                                'market_cap': 11169253713.432798,
#                                'price': 1.89419751555515e-05,
#                                'volume_24h': 325553779.29560196},
#                        'CAD': {'fully_diluted_market_cap': 10315397257.16205,
#                                'market_cap': 10315397257.16205,
#                                'price': 1.7493917102967712e-05,
#                                'volume_24h': 300666154.44197536},
#                        'EUR': {'fully_diluted_market_cap': 7229026056.715005,
#                                'market_cap': 7229026056.715005,
#                                'price': 1.2259729743666542e-05,
#                                'volume_24h': 210706714.50139698},
#                        'GBP': {'fully_diluted_market_cap': 6401991971.852797,
#                                'market_cap': 6401991971.852797,
#                                'price': 1.0857159841488227e-05,
#                                'volume_24h': 186600889.81148392},
#                        'JPY': {'fully_diluted_market_cap': 1014789462841.3746,
#                                'market_cap': 1014789462841.3746,
#                                'price': 0.0017209848828251728,
#                                'volume_24h': 29578390221.366608},
#                        'NZD': {'fully_diluted_market_cap': 12243287677.717451,
#                                'market_cap': 12243287677.717451,
#                                'price': 2.076343298878445e-05,
#                                'volume_24h': 356858987.78452635},
#                        'USD': {'fully_diluted_market_cap': 7721276508.445211,
#                                'market_cap': 7721276508.445211,
#                                'price': 1.309453894992253e-05,
#                                'volume_24h': 225054494.4903147}},
#              'status': 'recent',
#              'total_supply': 589656232874918.6,
#              'updated_at': '2023-02-11T01:22:14.563807',
#              'volume_24h': 225054494.4903147,
#              'website': ''},
#             {'asset_id': 'AGIX',
#              'change_1h': -0.4895587858410792,
#              'change_24h': 4.666969704986903,
#              'change_7d': 59.91348369200614,
#              'circulating_supply': 0,
#              'created_at': '2021-09-21T01:27:16',
#              'description': '',
#              'ethereum_contract_address': '',
#              'fully_diluted_market_cap': 0,
#              'market_cap': 0,
#              'max_supply': 0,
#              'name': '',
#              'pegged': '',
#              'price': 0.42990688290258655,
#              'quote': {'AUD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.6218840942994454,
#                                'volume_24h': 321490873.82519007},
#                        'CAD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.5743428921212679,
#                                'volume_24h': 296913846.0943557},
#                        'EUR': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.40249925709365975,
#                                'volume_24h': 208077098.39049652},
#                        'GBP': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.35645147664072274,
#                                'volume_24h': 184272113.97100928},
#                        'JPY': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 56.50166449749042,
#                                'volume_24h': 29209252428.844624},
#                        'NZD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.6816843868044602,
#                                'volume_24h': 352405393.8598221},
#                        'USD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.42990688290258655,
#                                'volume_24h': 222245818.33615083}},
#              'status': 'recent',
#              'total_supply': 0,
#              'updated_at': '2023-02-11T01:22:09.844716',
#              'volume_24h': 222245818.33615083,
#              'website': ''},
#             {'asset_id': 'LDO',
#              'change_1h': 2.0120724346076426,
#              'change_24h': -17.87257019438444,
#              'change_7d': 0.30775994724115713,
#              'circulating_supply': 0,
#              'created_at': '2021-09-21T01:53:50',
#              'description': '',
#              'ethereum_contract_address': '',
#              'fully_diluted_market_cap': 0,
#              'market_cap': 0,
#              'max_supply': 0,
#              'name': 'Lido DAO',
#              'pegged': '',
#              'price': 2.2815,
#              'quote': {'AUD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 3.3003159929999994,
#                                'volume_24h': 280308216.7990877},
#                        'CAD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 3.048016583329722,
#                                'volume_24h': 258879481.5585413},
#                        'EUR': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 2.1360487388783316,
#                                'volume_24h': 181422631.73007792},
#                        'GBP': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 1.8916748633217009,
#                                'volume_24h': 160667041.83055},
#                        'JPY': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 299.8522533081519,
#                                'volume_24h': 25467576621.83544},
#                        'NZD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 3.6176739437009338,
#                                'volume_24h': 307262617.96451324},
#                        'USD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 2.2815,
#                                'volume_24h': 193776352.92606926}},
#              'status': 'recent',
#              'total_supply': 0,
#              'updated_at': '2023-02-11T01:22:12.738931',
#              'volume_24h': 193776352.92606926,
#              'website': ''},
#             {'asset_id': 'BNB',
#              'change_1h': 0.7467570953738895,
#              'change_24h': 0.14832235182495007,
#              'change_7d': -6.769809923882199,
#              'circulating_supply': 157219628.63,
#              'created_at': '2021-09-21T01:27:16',
#              'description': 'BNB is the cryptocurrency coin that powers the '
#                             "Binance ecosystem. As one of the world's most "
#                             'popular utility tokens, not only can you buy or '
#                             'sell BNB like any other cryptocurrency, but BNB '
#                             'comes with a wide range of applications and '
#                             'benefits.',
#              'ethereum_contract_address': '',
#              'fully_diluted_market_cap': 48238716228.88172,
#              'market_cap': 48238716228.88172,
#              'max_supply': 0,
#              'name': 'Binance Coin',
#              'pegged': '',
#              'price': 306.8237512658582,
#              'quote': {'AUD': {'fully_diluted_market_cap': 69779972234.04207,
#                                'market_cap': 69779972234.04207,
#                                'price': 443.83753378696724,
#                                'volume_24h': 277511153.34255785},
#                        'CAD': {'fully_diluted_market_cap': 64445499462.7079,
#                                'market_cap': 64445499462.7079,
#                                'price': 409.9074652718692,
#                                'volume_24h': 256296245.34170288},
#                        'EUR': {'fully_diluted_market_cap': 45163378902.394264,
#                                'market_cap': 45163378902.394264,
#                                'price': 287.2629791581659,
#                                'volume_24h': 179612300.87643978},
#                        'GBP': {'fully_diluted_market_cap': 39996479039.70377,
#                                'market_cap': 39996479039.70377,
#                                'price': 254.39876298036114,
#                                'volume_24h': 159063821.21681},
#                        'JPY': {'fully_diluted_market_cap': 6339902589490.555,
#                                'market_cap': 6339902589490.555,
#                                'price': 40325.13398445212,
#                                'volume_24h': 25213447689.374043},
#                        'NZD': {'fully_diluted_market_cap': 76490005162.74765,
#                                'market_cap': 76490005162.74765,
#                                'price': 486.5168925106604,
#                                'volume_24h': 304196589.2548295},
#                        'USD': {'fully_diluted_market_cap': 48238716228.88172,
#                                'market_cap': 48238716228.88172,
#                                'price': 306.8237512658582,
#                                'volume_24h': 191842750.11663884}},
#              'status': 'recent',
#              'total_supply': 157219628.63,
#              'updated_at': '2023-02-11T01:22:10.472113',
#              'volume_24h': 191842750.11663884,
#              'website': ''},
#             {'asset_id': 'GRT',
#              'change_1h': 0.5582498145972896,
#              'change_24h': 9.71202427695462,
#              'change_7d': 68.17957055360179,
#              'circulating_supply': 0,
#              'created_at': '2021-09-21T01:53:50',
#              'description': '',
#              'ethereum_contract_address': '',
#              'fully_diluted_market_cap': 0,
#              'market_cap': 0,
#              'max_supply': 0,
#              'name': 'The Graph',
#              'pegged': '',
#              'price': 0.16389605843080837,
#              'quote': {'AUD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.23708471743539747,
#                                'volume_24h': 262517329.15719736},
#                        'CAD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.21896029105390358,
#                                'volume_24h': 242448654.72873065},
#                        'EUR': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.15344727982391304,
#                                'volume_24h': 169907915.20245177},
#                        'GBP': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.13589219983829276,
#                                'volume_24h': 150469662.24031487},
#                        'JPY': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 21.54047882042622,
#                                'volume_24h': 23851174507.890053},
#                        'NZD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.25988275260154337,
#                                'volume_24h': 287760960.912919},
#                        'USD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.16389605843080837,
#                                'volume_24h': 181477557.82854998}},
#              'status': 'recent',
#              'total_supply': 0,
#              'updated_at': '2023-02-11T01:22:12.044605',
#              'volume_24h': 181477557.82854998,
#              'website': ''},
#             {'asset_id': 'XRP',
#              'change_1h': 0.10686637717672984,
#              'change_24h': -0.4345030391076786,
#              'change_7d': -6.322245093539188,
#              'circulating_supply': 50799084881,
#              'created_at': '2021-09-21T01:53:50',
#              'description': 'XRP is a digital asset built for payments. It is '
#                             'the native digital asset on the XRP Ledger—an '
#                             'open-source, permissionless and decentralized '
#                             'blockchain technology that can settle '
#                             'transactions in 3-5 seconds.\r\n'
#                             'XRP can be sent directly without needing a '
#                             'central intermediary, making it a convenient '
#                             'instrument in bridging two different currencies '
#                             'quickly and efficiently.',
#              'ethereum_contract_address': '',
#              'fully_diluted_market_cap': 19401192672.19626,
#              'market_cap': 19401192672.19626,
#              'max_supply': 0,
#              'name': 'XRP',
#              'pegged': '',
#              'price': 0.38192012154637733,
#              'quote': {'AUD': {'fully_diluted_market_cap': 28064898732.99308,
#                                'market_cap': 28064898732.99308,
#                                'price': 0.552468588730227,
#                                'volume_24h': 260459461.10735515},
#                        'CAD': {'fully_diluted_market_cap': 25919420118.881996,
#                                'market_cap': 25919420118.881996,
#                                'price': 0.5102339969233667,
#                                'volume_24h': 240548104.61306676},
#                        'EUR': {'fully_diluted_market_cap': 18164318711.453144,
#                                'market_cap': 18164318711.453144,
#                                'price': 0.3575717703183864,
#                                'volume_24h': 168576010.48121697},
#                        'GBP': {'fully_diluted_market_cap': 16086236465.682596,
#                                'market_cap': 16086236465.682596,
#                                'price': 0.31666390257552085,
#                                'volume_24h': 149290133.5920957},
#                        'JPY': {'fully_diluted_market_cap': 2549853753944.1826,
#                                'market_cap': 2549853753944.1826,
#                                'price': 50.1948757525332,
#                                'volume_24h': 23664205631.85975},
#                        'NZD': {'fully_diluted_market_cap': 30763615694.466755,
#                                'market_cap': 30763615694.466755,
#                                'price': 0.6055938953729665,
#                                'volume_24h': 285505208.54275835},
#                        'USD': {'fully_diluted_market_cap': 19401192672.19626,
#                                'market_cap': 19401192672.19626,
#                                'price': 0.38192012154637733,
#                                'volume_24h': 180054958.9120604}},
#              'status': 'recent',
#              'total_supply': 50799084881,
#              'updated_at': '2023-02-11T01:22:16.233827',
#              'volume_24h': 180054958.9120604,
#              'website': ''},
#             {'asset_id': 'DOGE',
#              'change_1h': 1.3440764702023082,
#              'change_24h': 0.41458583747889766,
#              'change_7d': -12.98730793441582,
#              'circulating_supply': 132670764299.89409,
#              'created_at': '2021-09-21T01:27:16',
#              'description': 'Dogecoin is a peer-to-peer, open-source '
#                             'cryptocurrency. It is considered an altcoin and '
#                             'an almost sarcastic meme coin. Launched in '
#                             'December 2013, Dogecoin has the image of a Shiba '
#                             'Inu dog as its logo.\r\n'
#                             'While it was created seemingly as a joke, '
#                             "Dogecoin's blockchain still has merit. Its "
#                             'underlying technology is derived from Litecoin.',
#              'ethereum_contract_address': '',
#              'fully_diluted_market_cap': 10864332274.179308,
#              'market_cap': 10864332274.179308,
#              'max_supply': 0,
#              'name': 'Dogecoin',
#              'pegged': '',
#              'price': 0.08188942252281863,
#              'quote': {'AUD': {'fully_diluted_market_cap': 15715857794.319538,
#                                'market_cap': 15715857794.319538,
#                                'price': 0.11845758089397006,
#                                'volume_24h': 252476081.11582786},
#                        'CAD': {'fully_diluted_market_cap': 14514426885.164516,
#                                'market_cap': 14514426885.164516,
#                                'price': 0.10940184871744274,
#                                'volume_24h': 233175030.44174212},
#                        'EUR': {'fully_diluted_market_cap': 10171704252.910748,
#                                'market_cap': 10171704252.910748,
#                                'price': 0.0766687695408028,
#                                'volume_24h': 163408963.20481744},
#                        'GBP': {'fully_diluted_market_cap': 9008014144.133108,
#                                'market_cap': 9008014144.133108,
#                                'price': 0.06789750697275737,
#                                'volume_24h': 144714220.47154936},
#                        'JPY': {'fully_diluted_market_cap': 1427873992154.786,
#                                'market_cap': 1427873992154.786,
#                                'price': 10.762536868538458,
#                                'volume_24h': 22938870698.91635},
#                        'NZD': {'fully_diluted_market_cap': 17227092607.498398,
#                                'market_cap': 17227092607.498398,
#                                'price': 0.12984844625269223,
#                                'volume_24h': 276754147.78394943},
#                        'USD': {'fully_diluted_market_cap': 10864332274.179308,
#                                'market_cap': 10864332274.179308,
#                                'price': 0.08188942252281863,
#                                'volume_24h': 174536068.75448102}},
#              'status': 'recent',
#              'total_supply': 132670764299.89409,
#              'updated_at': '2023-02-11T01:22:11.314731',
#              'volume_24h': 174536068.75448102,
#              'website': ''},
#             {'asset_id': 'FET',
#              'change_1h': 2.7972988956501683,
#              'change_24h': 3.8198088422015712,
#              'change_7d': 33.53507308437332,
#              'circulating_supply': 0,
#              'created_at': '2021-09-21T01:53:50',
#              'description': '',
#              'ethereum_contract_address': '',
#              'fully_diluted_market_cap': 0,
#              'market_cap': 0,
#              'max_supply': 0,
#              'name': 'Fetch.AI',
#              'pegged': '',
#              'price': 0.42817918498402996,
#              'quote': {'AUD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.6193848836609684,
#                                'volume_24h': 250224114.70018536},
#                        'CAD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.5720347387542968,
#                                'volume_24h': 231095220.20704383},
#                        'EUR': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.40088170418544344,
#                                'volume_24h': 161951433.06760263},
#                        'GBP': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.3550189792819909,
#                                'volume_24h': 143423438.53716764},
#                        'JPY': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 56.27459716726249,
#                                'volume_24h': 22734266895.6633},
#                        'NZD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.6789448524005379,
#                                'volume_24h': 274285632.57472736},
#                        'USD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.42817918498402996,
#                                'volume_24h': 172979290.13443804}},
#              'status': 'recent',
#              'total_supply': 0,
#              'updated_at': '2023-02-11T01:22:11.677568',
#              'volume_24h': 172979290.13443804,
#              'website': ''},
#             {'asset_id': 'MINA',
#              'change_1h': 0.5525622162571446,
#              'change_24h': 17.38655996705621,
#              'change_7d': 2.2876571736187965,
#              'circulating_supply': 0,
#              'created_at': '2021-09-21T01:53:50',
#              'description': '',
#              'ethereum_contract_address': '',
#              'fully_diluted_market_cap': 0,
#              'market_cap': 0,
#              'max_supply': 0,
#              'name': 'Mina',
#              'pegged': '',
#              'price': 0.8586967783431606,
#              'quote': {'AUD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 1.24215240442845,
#                                'volume_24h': 215385848.24820393},
#                        'CAD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 1.1471935219994565,
#                                'volume_24h': 198920236.32509923},
#                        'EUR': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.8039527374353691,
#                                'volume_24h': 139403217.90356994},
#                        'GBP': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.7119768182367229,
#                                'volume_24h': 123454843.6908871},
#                        'JPY': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 112.85652592357982,
#                                'volume_24h': 19569014623.113277},
#                        'NZD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 1.3615976158457106,
#                                'volume_24h': 236097323.01456347},
#                        'USD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.8586967783431606,
#                                'volume_24h': 148895685.69208133}},
#              'status': 'recent',
#              'total_supply': 0,
#              'updated_at': '2023-02-11T01:22:13.139611',
# ...
#                                'market_cap': 0,
#                                'price': 14.113565900783462,
#                                'volume_24h': 19712629.83834997},
#                        'EUR': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 9.890781043753767,
#                                'volume_24h': 13814602.6949053},
#                        'GBP': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 8.75922985208321,
#                                'volume_24h': 12234148.120820146},
#                        'JPY': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 1388.438816477797,
#                                'volume_24h': 1939253384.6392572},
#                        'NZD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 16.751312932882115,
#                                'volume_24h': 23396810.804131307},
#                        'USD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 10.56427999071493,
#                                'volume_24h': 14755288.80720998}},
#              'status': 'recent',
#              'total_supply': 0,
#              'updated_at': '2023-02-11T01:22:10.045590',
#              'volume_24h': 14755288.80720998,
#              'website': ''},
#             {'asset_id': 'BCH',
#              'change_1h': 0.20589240742019552,
#              'change_24h': -4.499319470970367,
#              'change_7d': -9.397508388234813,
#              'circulating_supply': 0,
#              'created_at': '2021-09-21T01:27:16',
#              'description': '',
#              'ethereum_contract_address': '',
#              'fully_diluted_market_cap': 0,
#              'market_cap': 0,
#              'max_supply': 0,
#              'name': 'Bitcoin Cash',
#              'pegged': '',
#              'price': 124.42169238453477,
#              'quote': {'AUD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 179.98286270120812,
#                                'volume_24h': 20786552.125422694},
#                        'CAD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 166.2237044549688,
#                                'volume_24h': 19197481.611736096},
#                        'EUR': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 116.48950212890345,
#                                'volume_24h': 13453587.034487901},
#                        'GBP': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 103.16256319779511,
#                                'volume_24h': 11914434.325134149},
#                        'JPY': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 16352.454447475991,
#                                'volume_24h': 1888575065.7013981},
#                        'NZD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 197.28999104567362,
#                                'volume_24h': 22785384.236849032},
#                        'USD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 124.42169238453477,
#                                'volume_24h': 14369690.288669242}},
#              'status': 'recent',
#              'total_supply': 0,
#              'updated_at': '2023-02-11T01:22:10.336896',
#              'volume_24h': 14369690.288669242,
#              'website': ''},
#             {'asset_id': 'COCOS',
#              'change_1h': 0.2778863616971479,
#              'change_24h': 4.183770221402999,
#              'change_7d': -0.8691259838954914,
#              'circulating_supply': 0,
#              'created_at': '2021-09-21T01:27:16',
#              'description': '',
#              'ethereum_contract_address': '',
#              'fully_diluted_market_cap': 0,
#              'market_cap': 0,
#              'max_supply': 0,
#              'name': 'Cocos',
#              'pegged': '',
#              'price': 0.68625096083722,
#              'quote': {'AUD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.9926999874042051,
#                                'volume_24h': 19247425.673254374},
#                        'CAD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.916811005460356,
#                                'volume_24h': 17776016.830787625},
#                        'EUR': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.6425007667983289,
#                                'volume_24h': 12457425.114204645},
#                        'GBP': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.56899570131323,
#                                'volume_24h': 11032237.945388786},
#                        'JPY': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 90.19237209814803,
#                                'volume_24h': 1748736778.765323},
#                        'NZD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 1.0881578872936843,
#                                'volume_24h': 21098255.587992348},
#                        'USD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.68625096083722,
#                                'volume_24h': 13305696.111120794}},
#              'status': 'recent',
#              'total_supply': 0,
#              'updated_at': '2023-02-11T01:22:10.861962',
#              'volume_24h': 13305696.111120794,
#              'website': ''},
#             {'asset_id': 'XLM',
#              'change_1h': 1.2779954717531457,
#              'change_24h': 1.5873440682299118,
#              'change_7d': -6.139002400467871,
#              'circulating_supply': 0,
#              'created_at': '2021-09-21T01:53:50',
#              'description': '',
#              'ethereum_contract_address': '',
#              'fully_diluted_market_cap': 0,
#              'market_cap': 0,
#              'max_supply': 0,
#              'name': 'Stellar',
#              'pegged': '',
#              'price': 0.08674918495120337,
#              'quote': {'AUD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.12548749615348298,
#                                'volume_24h': 19189429.996922538},
#                        'CAD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.11589434771930968,
#                                'volume_24h': 17722454.752612144},
#                        'EUR': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.08121871010902526,
#                                'volume_24h': 12419888.832360188},
#                        'GBP': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.07192691325261302,
#                                'volume_24h': 10998995.9881547},
#                        'JPY': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 11.401244172809097,
#                                'volume_24h': 1743467545.6776075},
#                        'NZD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.1375543572365819,
#                                'volume_24h': 21034683.05507186},
#                        'USD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.08674918495120337,
#                                'volume_24h': 13265603.848491479}},
#              'status': 'recent',
#              'total_supply': 0,
#              'updated_at': '2023-02-11T01:22:16.148530',
#              'volume_24h': 13265603.848491479,
#              'website': ''},
#             {'asset_id': 'SNX',
#              'change_1h': 1.8689516914914273,
#              'change_24h': 1.131728134073022,
#              'change_7d': -5.454536429033614,
#              'circulating_supply': 0,
#              'created_at': '2021-09-21T01:53:50',
#              'description': '',
#              'ethereum_contract_address': '',
#              'fully_diluted_market_cap': 0,
#              'market_cap': 0,
#              'max_supply': 0,
#              'name': 'Synthetix Network Token',
#              'pegged': '',
#              'price': 2.406953913285446,
#              'quote': {'AUD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 3.481792020350599,
#                                'volume_24h': 18870991.77543193},
#                        'CAD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 3.2156193044069292,
#                                'volume_24h': 17428360.192597874},
#                        'EUR': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 2.2535046552757585,
#                                'volume_24h': 12213787.488468153},
#                        'GBP': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 1.9956932785167125,
#                                'volume_24h': 10816473.593210608},
#                        'JPY': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 316.3403701545102,
#                                'volume_24h': 1714535643.8670166},
#                        'NZD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 3.816600681911793,
#                                'volume_24h': 20685623.856192585},
#                        'USD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 2.406953913285446,
#                                'volume_24h': 13045468.320902068}},
#              'status': 'recent',
#              'total_supply': 0,
#              'updated_at': '2023-02-11T01:22:14.675301',
#              'volume_24h': 13045468.320902068,
#              'website': ''},
#             {'asset_id': 'ACH',
#              'change_1h': 1.9747668678003563,
#              'change_24h': 5.617939977274276,
#              'change_7d': 0.28559642052488415,
#              'circulating_supply': 0,
#              'created_at': '2021-09-21T01:27:16',
#              'description': '',
#              'ethereum_contract_address': '',
#              'fully_diluted_market_cap': 0,
#              'market_cap': 0,
#              'max_supply': 0,
#              'name': 'Alchemy Pay',
#              'pegged': '',
#              'price': 0.015801500000000003,
#              'quote': {'AUD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.02285774409966667,
#                                'volume_24h': 18685309.40670355},
#                        'CAD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.021110337077135485,
#                                'volume_24h': 17256872.692517135},
#                        'EUR': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.01479411533963882,
#                                'volume_24h': 12093609.120579915},
#                        'GBP': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.013101599979302153,
#                                'volume_24h': 10710044.18759293},
#                        'JPY': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 2.076754495134238,
#                                'volume_24h': 1697665357.2699478},
#                        'NZD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.025055741758224993,
#                                'volume_24h': 20482086.29537172},
#                        'USD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.015801500000000003,
#                                'volume_24h': 12917106.574586768}},
#              'status': 'recent',
#              'total_supply': 0,
#              'updated_at': '2023-02-11T01:22:09.774523',
#              'volume_24h': 12917106.574586768,
#              'website': ''},
#             {'asset_id': 'VET',
#              'change_1h': 0.7550479007466488,
#              'change_24h': 1.3726870708792118,
#              'change_7d': -3.718935865809539,
#              'circulating_supply': 0,
#              'created_at': '2021-09-21T01:53:50',
#              'description': '',
#              'ethereum_contract_address': '',
#              'fully_diluted_market_cap': 0,
#              'market_cap': 0,
#              'max_supply': 0,
#              'name': 'Ve Chain',
#              'pegged': '',
#              'price': 0.023582968462930464,
#              'quote': {'AUD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.034114068805883864,
#                                'volume_24h': 18398715.906662226},
#                        'CAD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.03150614900686123,
#                                'volume_24h': 16992188.41905567},
#                        'EUR': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.022079495965044965,
#                                'volume_24h': 11908118.49312714},
#                        'GBP': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.01955349929600437,
#                                'volume_24h': 10545774.547604077},
#                        'JPY': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 3.0994548469448975,
#                                'volume_24h': 1671626727.3468945},
#                        'NZD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.03739447316391164,
#                                'volume_24h': 20167934.00215718},
#                        'USD': {'fully_diluted_market_cap': 0,
#                                'market_cap': 0,
#                                'price': 0.023582968462930464,
#                                'volume_24h': 12718985.22144024}},
#              'status': 'recent',
#              'total_supply': 0,
#              'updated_at': '2023-02-11T01:22:15.594957',
#              'volume_24h': 12718985.22144024,
#              'website': ''}],
#  'next': '12718985'}

# %%
crytocurrency_df = pd.DataFrame(columns=['coin','price','one hour change','one day change', 'one week change', 'update'])
crytocurrency_df
# Out:
# Empty DataFrame
# Columns: [coin, price, one hour change, one day change, one week change, update]
# Index: []

# %%
first_main_info = main_info['assets'][0]

first_id = main_info['assets'][0]['asset_id']
first_price = main_info['assets'][0]['price']
first_change_1h = main_info['assets'][0]['change_1h']
first_change_24h = main_info['assets'][0]['change_24h']
first_change_7d = main_info['assets'][0]['change_7d']

first_created_at = main_info['assets'][0]['created_at']
first_description = main_info['assets'][0]['description']
first_updated_at = main_info['assets'][0]['updated_at']

# %%
def get_first_currency(main_info):
    first_main_info = main_info['assets'][0]
    first_id = main_info['assets'][0]['asset_id']
    first_price = main_info['assets'][0]['price']
    first_change_1h = main_info['assets'][0]['change_1h']
    first_change_24h = main_info['assets'][0]['change_24h']
    first_change_7d = main_info['assets'][0]['change_7d']
    first_created_at = main_info['assets'][0]['created_at']
    first_description = main_info['assets'][0]['description']
    first_updated_at = main_info['assets'][0]['updated_at']

    return first_main_info, first_id, first_price, first_change_1h, first_change_24h, first_change_7d, first_updated_at

# %%
class First:

    for coin in first_main_info:
        print(first_id)
        break
    for price in first_main_info:
        print(first_price)
        break
    for one_hour_change in first_main_info:
        print(first_change_1h)
        break
    for one_day_change in first_main_info:
        print(first_change_24h)
        break
    for one_week_change in first_main_info:
        print(first_change_7d)
        break
    for update in first_main_info:
        print(first_updated_at)
        break
# Out:
# USDT
# 1.000115000015095
# -0.002999565559667105
# -0.010997523851546991
# 0.1535617876537711
# 2023-02-11T01:22:15.499366

# %%
crytocurrency_df = crytocurrency_df.append({'coin': first_id,
                                            'price': first_price,
                                            'one hour change': first_change_1h,
                                            'one day change': first_change_24h,
                                            'one week change': first_change_7d,
                                            'update':first_updated_at}, ignore_index=True)
crytocurrency_df
# Out:
# /var/folders/02/lzvd5scj4zb274qzdzm7r7p80000gn/T/ipykernel_37543/2166909319.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   crytocurrency_df = crytocurrency_df.append({'coin': first_id,
#    coin     price  one hour change  one day change  one week change  \
# 0  USDT  1.000115           -0.003       -0.010998         0.153562
#
#                        update
# 0  2023-02-11T01:22:15.499366

# %%
second_main_info = main_info['assets'][1]

second_id = main_info['assets'][1]['asset_id']
second_price = main_info['assets'][1]['price']
second_change_1h = main_info['assets'][1]['change_1h']
second_change_24h = main_info['assets'][1]['change_24h']
second_change_7d = main_info['assets'][1]['change_7d']

second_created_at = main_info['assets'][1]['created_at']
second_description = main_info['assets'][1]['description']
second_updated_at = main_info['assets'][1]['updated_at']

# %%
class Second:

    for coin in second_main_info:
        print(second_id)
        break
    for price in second_main_info:
        print(second_price)
        break
    for one_hour_change in second_main_info:
        print(second_change_1h)
        break
    for one_day_change in second_main_info:
        print(second_change_24h)
        break
    for one_week_change in second_main_info:
        print(second_change_7d)
        break
    for update in second_main_info:
        print(second_updated_at)
        break
# Out:
# BTC
# 21701.344101122428
# 0.3760792679215792
# -0.6954589238826103
# -6.994883959207889
# 2023-02-11T01:22:10.601991

# %%
crytocurrency_df = crytocurrency_df.append({'coin': second_id,
                                            'price': second_price,
                                            'one hour change': second_change_1h,
                                            'one day change': second_change_24h,
                                            'one week change': second_change_7d,
                                            'update':second_updated_at}, ignore_index=True)
crytocurrency_df
# Out:
# /var/folders/02/lzvd5scj4zb274qzdzm7r7p80000gn/T/ipykernel_37543/403869589.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   crytocurrency_df = crytocurrency_df.append({'coin': second_id,
#    coin         price  one hour change  one day change  one week change  \
# 0  USDT      1.000115        -0.003000       -0.010998         0.153562
# 1   BTC  21701.344101         0.376079       -0.695459        -6.994884
#
#                        update
# 0  2023-02-11T01:22:15.499366
# 1  2023-02-11T01:22:10.601991

# %%
third_main_info = main_info['assets'][2]

third_id = main_info['assets'][2]['asset_id']
third_price = main_info['assets'][2]['price']
third_change_1h = main_info['assets'][2]['change_1h']
third_change_24h = main_info['assets'][2]['change_24h']
third_change_7d = main_info['assets'][2]['change_7d']

third_created_at = main_info['assets'][2]['created_at']
third_description = main_info['assets'][2]['description']
third_updated_at = main_info['assets'][2]['updated_at']

# %%
class Third:

    for coin in third_main_info:
        print(third_id)
        break
    for price in third_main_info:
        print(third_price)
        break
    for one_hour_change in third_main_info:
        print(third_change_1h)
        break
    for one_day_change in third_main_info:
        print(third_change_24h)
        break
    for one_week_change in third_main_info:
        print(third_change_7d)
        break
    for update in third_main_info:
        print(third_updated_at)
        break
# Out:
# BUSD
# 0.9995000000000002
# -0.04999999999998339
# -0.04999999999998339
# -1.1107784138320721e-14
# 2023-02-11T01:22:10.678256

# %%
crytocurrency_df = crytocurrency_df.append({'coin': third_id,
                                            'price': third_price,
                                            'one hour change': third_change_1h,
                                            'one day change': third_change_24h,
                                            'one week change': third_change_7d,
                                            'update':third_updated_at}, ignore_index=True)
crytocurrency_df
# Out:
# /var/folders/02/lzvd5scj4zb274qzdzm7r7p80000gn/T/ipykernel_37543/1545298032.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   crytocurrency_df = crytocurrency_df.append({'coin': third_id,
#    coin         price  one hour change  one day change  one week change  \
# 0  USDT      1.000115        -0.003000       -0.010998     1.535618e-01
# 1   BTC  21701.344101         0.376079       -0.695459    -6.994884e+00
# 2  BUSD      0.999500        -0.050000       -0.050000    -1.110778e-14
#
#                        update
# 0  2023-02-11T01:22:15.499366
# 1  2023-02-11T01:22:10.601991
# 2  2023-02-11T01:22:10.678256

# %%
fourth_main_info = main_info['assets'][3]

fourth_id = main_info['assets'][3]['asset_id']
fourth_price = main_info['assets'][3]['price']
fourth_change_1h = main_info['assets'][3]['change_1h']
fourth_change_24h = main_info['assets'][3]['change_24h']
fourth_change_7d = main_info['assets'][3]['change_7d']

fourth_created_at = main_info['assets'][3]['created_at']
fourth_description = main_info['assets'][3]['description']
fourth_updated_at = main_info['assets'][3]['updated_at']

# %%
class Fourth:

    for coin in fourth_main_info:
        print(fourth_id)
        break
    for price in fourth_main_info:
        print(fourth_price)
        break
    for one_hour_change in fourth_main_info:
        print(fourth_change_1h)
        break
    for one_day_change in fourth_main_info:
        print(fourth_change_24h)
        break
    for one_week_change in fourth_main_info:
        print(fourth_change_7d)
        break
    for update in fourth_main_info:
        print(fourth_updated_at)
        break
# Out:
# ETH
# 1517.175
# 0.42528545424457753
# -2.068545740411442
# -8.18488077948093
# 2023-02-11T01:22:11.511573

# %%
crytocurrency_df = crytocurrency_df.append({'coin': fourth_id,
                                            'price': fourth_price,
                                            'one hour change': fourth_change_1h,
                                            'one day change': fourth_change_24h,
                                            'one week change': fourth_change_7d,
                                            'update':fourth_updated_at}, ignore_index=True)
crytocurrency_df
# Out:
# /var/folders/02/lzvd5scj4zb274qzdzm7r7p80000gn/T/ipykernel_37543/462955676.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   crytocurrency_df = crytocurrency_df.append({'coin': fourth_id,
#    coin         price  one hour change  one day change  one week change  \
# 0  USDT      1.000115        -0.003000       -0.010998     1.535618e-01
# 1   BTC  21701.344101         0.376079       -0.695459    -6.994884e+00
# 2  BUSD      0.999500        -0.050000       -0.050000    -1.110778e-14
# 3   ETH   1517.175000         0.425285       -2.068546    -8.184881e+00
#
#                        update
# 0  2023-02-11T01:22:15.499366
# 1  2023-02-11T01:22:10.601991
# 2  2023-02-11T01:22:10.678256
# 3  2023-02-11T01:22:11.511573

# %%
fifth_main_info = main_info['assets'][4]

fifth_id = main_info['assets'][4]['asset_id']
fifth_price = main_info['assets'][4]['price']
fifth_change_1h = main_info['assets'][4]['change_1h']
fifth_change_24h = main_info['assets'][4]['change_24h']
fifth_change_7d = main_info['assets'][4]['change_7d']

fifth_created_at =  main_info['assets'][4]['created_at']
fifth_description = main_info['assets'][4]['description']
fifth_updated_at = main_info['assets'][4]['updated_at']

# %%
class Fifth:

    for coin in fifth_main_info:
        print(fifth_id)
        break
    for price in fifth_main_info:
        print(fifth_price)
        break
    for one_hour_change in fifth_main_info:
        print(fifth_change_1h)
        break
    for one_day_change in fifth_main_info:
        print(fifth_change_24h)
        break
    for one_week_change in fifth_main_info:
        print(fifth_change_7d)
        break
    for update in fifth_main_info:
        print(fifth_updated_at)
        break
# Out:
# MATIC
# 1.2274364833731852
# 0.43246191181447796
# -2.7480874855236244
# 0.2514317254272359
# 2023-02-11T01:22:13.004855

# %%
crytocurrency_df = crytocurrency_df.append({'coin': fifth_id,
                                            'price': fifth_price,
                                            'one hour change': fifth_change_1h,
                                            'one day change': fifth_change_24h,
                                            'one week change': fifth_change_7d,
                                            'update':fifth_updated_at}, ignore_index=True)
crytocurrency_df
# Out:
# /var/folders/02/lzvd5scj4zb274qzdzm7r7p80000gn/T/ipykernel_37543/1698772274.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   crytocurrency_df = crytocurrency_df.append({'coin': fifth_id,
#     coin         price  one hour change  one day change  one week change  \
# 0   USDT      1.000115        -0.003000       -0.010998     1.535618e-01
# 1    BTC  21701.344101         0.376079       -0.695459    -6.994884e+00
# 2   BUSD      0.999500        -0.050000       -0.050000    -1.110778e-14
# 3    ETH   1517.175000         0.425285       -2.068546    -8.184881e+00
# 4  MATIC      1.227436         0.432462       -2.748087     2.514317e-01
#
#                        update
# 0  2023-02-11T01:22:15.499366
# 1  2023-02-11T01:22:10.601991
# 2  2023-02-11T01:22:10.678256
# 3  2023-02-11T01:22:11.511573
# 4  2023-02-11T01:22:13.004855

# %%
sixth_main_info = main_info['assets'][5]

sixth_id = main_info['assets'][5]['asset_id']
sixth_price = main_info['assets'][5]['price']
sixth_change_1h = main_info['assets'][5]['change_1h']
sixth_change_24h = main_info['assets'][5]['change_24h']
sixth_change_7d = main_info['assets'][5]['change_7d']

sixth_created_at =  main_info['assets'][5]['created_at']
sixth_description = main_info['assets'][5]['description']
sixth_updated_at = main_info['assets'][5]['updated_at']

# %%
class Sixth:

    for coin in sixth_main_info:
        print(sixth_id)
        break
    for price in sixth_main_info:
        print(sixth_price)
        break
    for one_hour_change in sixth_main_info:
        print(sixth_change_1h)
        break
    for one_day_change in sixth_main_info:
        print(sixth_change_24h)
        break
    for one_week_change in sixth_main_info:
        print(sixth_change_7d)
        break
    for update in sixth_main_info:
        print(sixth_updated_at)
        break
# Out:
# APT
# 13.46
# -0.5908419497784217
# 2.9845173364113564
# -19.35290593169561
# 2023-02-11T01:22:10.024879

# %%
crytocurrency_df = crytocurrency_df.append({'coin': sixth_id,
                                            'price': sixth_price,
                                            'one hour change': sixth_change_1h,
                                            'one day change': sixth_change_24h,
                                            'one week change': sixth_change_7d,
                                            'update':sixth_updated_at}, ignore_index=True)
crytocurrency_df
# Out:
# /var/folders/02/lzvd5scj4zb274qzdzm7r7p80000gn/T/ipykernel_37543/3619653181.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   crytocurrency_df = crytocurrency_df.append({'coin': sixth_id,
#     coin         price  one hour change  one day change  one week change  \
# 0   USDT      1.000115        -0.003000       -0.010998     1.535618e-01
# 1    BTC  21701.344101         0.376079       -0.695459    -6.994884e+00
# 2   BUSD      0.999500        -0.050000       -0.050000    -1.110778e-14
# 3    ETH   1517.175000         0.425285       -2.068546    -8.184881e+00
# 4  MATIC      1.227436         0.432462       -2.748087     2.514317e-01
# 5    APT     13.460000        -0.590842        2.984517    -1.935291e+01
#
#                        update
# 0  2023-02-11T01:22:15.499366
# 1  2023-02-11T01:22:10.601991
# 2  2023-02-11T01:22:10.678256
# 3  2023-02-11T01:22:11.511573
# 4  2023-02-11T01:22:13.004855
# 5  2023-02-11T01:22:10.024879

# %%
seventh_main_info = main_info['assets'][6]

seventh_id = main_info['assets'][6]['asset_id']
seventh_price = main_info['assets'][6]['price']
seventh_change_1h = main_info['assets'][6]['change_1h']
seventh_change_24h = main_info['assets'][6]['change_24h']
seventh_change_7d = main_info['assets'][6]['change_7d']

seventh_created_at =  main_info['assets'][6]['created_at']
seventh_description = main_info['assets'][6]['description']
seventh_updated_at = main_info['assets'][6]['updated_at']

# %%
class Seventh:

    for coin in seventh_main_info:
        print(seventh_id)
        break
    for price in seventh_main_info:
        print(seventh_price)
        break
    for one_hour_change in seventh_main_info:
        print(seventh_change_1h)
        break
    for one_day_change in seventh_main_info:
        print(seventh_change_24h)
        break
    for one_week_change in seventh_main_info:
        print(seventh_change_7d)
        break
    for update in seventh_main_info:
        print(seventh_updated_at)
        break
# Out:
# SOL
# 20.413473027473287
# 1.0336721144867547
# -0.8763602830930455
# -16.461998741533197
# 2023-02-11T01:22:14.689289

# %%
crytocurrency_df = crytocurrency_df.append({'coin': seventh_id,
                                            'price': seventh_price,
                                            'one hour change': seventh_change_1h,
                                            'one day change': seventh_change_24h,
                                            'one week change': seventh_change_7d,
                                            'update':seventh_updated_at}, ignore_index=True)
crytocurrency_df
# Out:
# /var/folders/02/lzvd5scj4zb274qzdzm7r7p80000gn/T/ipykernel_37543/2530204870.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   crytocurrency_df = crytocurrency_df.append({'coin': seventh_id,
#     coin         price  one hour change  one day change  one week change  \
# 0   USDT      1.000115        -0.003000       -0.010998     1.535618e-01
# 1    BTC  21701.344101         0.376079       -0.695459    -6.994884e+00
# 2   BUSD      0.999500        -0.050000       -0.050000    -1.110778e-14
# 3    ETH   1517.175000         0.425285       -2.068546    -8.184881e+00
# 4  MATIC      1.227436         0.432462       -2.748087     2.514317e-01
# 5    APT     13.460000        -0.590842        2.984517    -1.935291e+01
# 6    SOL     20.413473         1.033672       -0.876360    -1.646200e+01
#
#                        update
# 0  2023-02-11T01:22:15.499366
# 1  2023-02-11T01:22:10.601991
# 2  2023-02-11T01:22:10.678256
# 3  2023-02-11T01:22:11.511573
# 4  2023-02-11T01:22:13.004855
# 5  2023-02-11T01:22:10.024879
# 6  2023-02-11T01:22:14.689289

# %%
eighth_main_info = main_info['assets'][7]

eighth_id = main_info['assets'][7]['asset_id']
eighth_price = main_info['assets'][7]['price']
eighth_change_1h = main_info['assets'][7]['change_1h']
eighth_change_24h = main_info['assets'][7]['change_24h']
eighth_change_7d = main_info['assets'][7]['change_7d']

eighth_created_at =  main_info['assets'][7]['created_at']
eighth_description = main_info['assets'][7]['description']
eighth_updated_at = main_info['assets'][7]['updated_at']

# %%
class Eighth:

    for coin in eighth_main_info:
        print(eighth_id)
        break
    for price in eighth_main_info:
        print(eighth_price)
        break
    for one_hour_change in eighth_main_info:
        print(eighth_change_1h)
        break
    for one_day_change in eighth_main_info:
        print(eighth_change_24h)
        break
    for one_week_change in eighth_main_info:
        print(eighth_change_7d)
        break
    for update in eighth_main_info:
        print(eighth_updated_at)
        break
# Out:
# SHIB
# 1.309453894992253e-05
# 2.5826709297813855
# 6.324733665949167
# -6.999013139754768
# 2023-02-11T01:22:14.563807

# %%
crytocurrency_df = crytocurrency_df.append({'coin': eighth_id,
                                            'price': eighth_price,
                                            'one hour change': eighth_change_1h,
                                            'one day change': eighth_change_24h,
                                            'one week change': eighth_change_7d,
                                            'update':eighth_updated_at}, ignore_index=True)
crytocurrency_df
# Out:
# /var/folders/02/lzvd5scj4zb274qzdzm7r7p80000gn/T/ipykernel_37543/274332385.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   crytocurrency_df = crytocurrency_df.append({'coin': eighth_id,
#     coin         price  one hour change  one day change  one week change  \
# 0   USDT      1.000115        -0.003000       -0.010998     1.535618e-01
# 1    BTC  21701.344101         0.376079       -0.695459    -6.994884e+00
# 2   BUSD      0.999500        -0.050000       -0.050000    -1.110778e-14
# 3    ETH   1517.175000         0.425285       -2.068546    -8.184881e+00
# 4  MATIC      1.227436         0.432462       -2.748087     2.514317e-01
# 5    APT     13.460000        -0.590842        2.984517    -1.935291e+01
# 6    SOL     20.413473         1.033672       -0.876360    -1.646200e+01
# 7   SHIB      0.000013         2.582671        6.324734    -6.999013e+00
#
#                        update
# 0  2023-02-11T01:22:15.499366
# 1  2023-02-11T01:22:10.601991
# 2  2023-02-11T01:22:10.678256
# 3  2023-02-11T01:22:11.511573
# 4  2023-02-11T01:22:13.004855
# 5  2023-02-11T01:22:10.024879
# 6  2023-02-11T01:22:14.689289
# 7  2023-02-11T01:22:14.563807

# %%
ninth_main_info = main_info['assets'][8]

ninth_id = main_info['assets'][8]['asset_id']
ninth_price = main_info['assets'][8]['price']
ninth_change_1h = main_info['assets'][8]['change_1h']
ninth_change_24h = main_info['assets'][8]['change_24h']
ninth_change_7d = main_info['assets'][8]['change_7d']

ninth_created_at =  main_info['assets'][8]['created_at']
ninth_description = main_info['assets'][8]['description']
ninth_updated_at = main_info['assets'][8]['updated_at']

# %%
class Ninth:

    for coin in ninth_main_info:
        print(ninth_id)
        break
    for price in ninth_main_info:
        print(ninth_price)
        break
    for one_hour_change in ninth_main_info:
        print(ninth_change_1h)
        break
    for one_day_change in ninth_main_info:
        print(ninth_change_24h)
        break
    for one_week_change in ninth_main_info:
        print(ninth_change_7d)
        break
    for update in ninth_main_info:
        print(ninth_updated_at)
        break
# Out:
# AGIX
# 0.42990688290258655
# -0.4895587858410792
# 4.666969704986903
# 59.91348369200614
# 2023-02-11T01:22:09.844716

# %%
crytocurrency_df = crytocurrency_df.append({'coin': ninth_id,
                                            'price': ninth_price,
                                            'one hour change': ninth_change_1h,
                                            'one day change': ninth_change_24h,
                                            'one week change': ninth_change_7d,
                                            'update':ninth_updated_at}, ignore_index=True)
crytocurrency_df
# Out:
# /var/folders/02/lzvd5scj4zb274qzdzm7r7p80000gn/T/ipykernel_37543/409097384.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   crytocurrency_df = crytocurrency_df.append({'coin': ninth_id,
#     coin         price  one hour change  one day change  one week change  \
# 0   USDT      1.000115        -0.003000       -0.010998     1.535618e-01
# 1    BTC  21701.344101         0.376079       -0.695459    -6.994884e+00
# 2   BUSD      0.999500        -0.050000       -0.050000    -1.110778e-14
# 3    ETH   1517.175000         0.425285       -2.068546    -8.184881e+00
# 4  MATIC      1.227436         0.432462       -2.748087     2.514317e-01
# 5    APT     13.460000        -0.590842        2.984517    -1.935291e+01
# 6    SOL     20.413473         1.033672       -0.876360    -1.646200e+01
# 7   SHIB      0.000013         2.582671        6.324734    -6.999013e+00
# 8   AGIX      0.429907        -0.489559        4.666970     5.991348e+01
#
#                        update
# 0  2023-02-11T01:22:15.499366
# 1  2023-02-11T01:22:10.601991
# 2  2023-02-11T01:22:10.678256
# 3  2023-02-11T01:22:11.511573
# 4  2023-02-11T01:22:13.004855
# 5  2023-02-11T01:22:10.024879
# 6  2023-02-11T01:22:14.689289
# 7  2023-02-11T01:22:14.563807
# 8  2023-02-11T01:22:09.844716

# %%
tenth_main_info = main_info['assets'][9]

tenth_id = main_info['assets'][9]['asset_id']
tenth_price = main_info['assets'][9]['price']
tenth_change_1h = main_info['assets'][9]['change_1h']
tenth_change_24h = main_info['assets'][9]['change_24h']
tenth_change_7d = main_info['assets'][9]['change_7d']

tenth_created_at =  main_info['assets'][9]['created_at']
tenth_description = main_info['assets'][9]['description']
tenth_updated_at = main_info['assets'][9]['updated_at']

# %%
class Tenth:
    for coin in tenth_main_info:
        print(tenth_id)
        break
    for price in tenth_main_info:
        print(tenth_price)
        break
    for one_hour_change in tenth_main_info:
        print(tenth_change_1h)
        break
    for one_day_change in tenth_main_info:
        print(tenth_change_24h)
        break
    for one_week_change in tenth_main_info:
        print(tenth_change_7d)
        break
    for update in tenth_main_info:
        print(tenth_updated_at)
        break
# Out:
# LDO
# 2.2815
# 2.0120724346076426
# -17.87257019438444
# 0.30775994724115713
# 2023-02-11T01:22:12.738931

# %%
crytocurrency_df = crytocurrency_df.append({'coin': tenth_id,
                                            'price': tenth_price,
                                            'one hour change': tenth_change_1h,
                                            'one day change': tenth_change_24h,
                                            'one week change': tenth_change_7d,
                                            'update':tenth_updated_at}, ignore_index=True)
crytocurrency_df
# Out:
# /var/folders/02/lzvd5scj4zb274qzdzm7r7p80000gn/T/ipykernel_37543/932090620.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   crytocurrency_df = crytocurrency_df.append({'coin': tenth_id,
#     coin         price  one hour change  one day change  one week change  \
# 0   USDT      1.000115        -0.003000       -0.010998     1.535618e-01
# 1    BTC  21701.344101         0.376079       -0.695459    -6.994884e+00
# 2   BUSD      0.999500        -0.050000       -0.050000    -1.110778e-14
# 3    ETH   1517.175000         0.425285       -2.068546    -8.184881e+00
# 4  MATIC      1.227436         0.432462       -2.748087     2.514317e-01
# 5    APT     13.460000        -0.590842        2.984517    -1.935291e+01
# 6    SOL     20.413473         1.033672       -0.876360    -1.646200e+01
# 7   SHIB      0.000013         2.582671        6.324734    -6.999013e+00
# 8   AGIX      0.429907        -0.489559        4.666970     5.991348e+01
# 9    LDO      2.281500         2.012072      -17.872570     3.077599e-01
#
#                        update
# 0  2023-02-11T01:22:15.499366
# 1  2023-02-11T01:22:10.601991
# 2  2023-02-11T01:22:10.678256
# 3  2023-02-11T01:22:11.511573
# 4  2023-02-11T01:22:13.004855
# 5  2023-02-11T01:22:10.024879
# 6  2023-02-11T01:22:14.689289
# 7  2023-02-11T01:22:14.563807
# 8  2023-02-11T01:22:09.844716
# 9  2023-02-11T01:22:12.738931
