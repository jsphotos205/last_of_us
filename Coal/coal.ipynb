# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
daily_df = pd.read_csv('/Users/johnchristophersloan/the_last_of_us/Coal/archive (2)/daily_csv.csv',parse_dates=['Date'])
monthly_df = pd.read_csv('/Users/johnchristophersloan/the_last_of_us/Coal/archive (2)/monthly_csv.csv',parse_dates=['Month'])
coal_price_df = pd.read_csv('/Users/johnchristophersloan/the_last_of_us/Coal/coal-prices.csv')
del coal_price_df['Code']

# %%
coal_price_df
# Out:
#                                                 Entity  Year  Coal - Prices
# 0                              Asian marker price (BP)  2001      36.894600
# 1                              Asian marker price (BP)  2002      30.406666
# 2                              Asian marker price (BP)  2003      36.529198
# 3                              Asian marker price (BP)  2004      72.416664
# 4                              Asian marker price (BP)  2005      61.840000
# ..                                                 ...   ...            ...
# 142  US Central Appalachian coal spot price index (BP)  2017      63.825291
# 143  US Central Appalachian coal spot price index (BP)  2018      72.844009
# 144  US Central Appalachian coal spot price index (BP)  2019      57.163982
# 145  US Central Appalachian coal spot price index (BP)  2020      42.766369
# 146  US Central Appalachian coal spot price index (BP)  2021      68.538139
#
# [147 rows x 3 columns]

# %%
daily_df
# Out:
#            Date  Price
# 0    1997-01-07   3.82
# 1    1997-01-08   3.80
# 2    1997-01-09   3.61
# 3    1997-01-10   3.92
# 4    1997-01-13   4.00
# ...         ...    ...
# 5948 2020-08-26   2.52
# 5949 2020-08-27   2.52
# 5950 2020-08-28   2.46
# 5951 2020-08-31   2.30
# 5952 2020-09-01   2.22
#
# [5953 rows x 2 columns]

# %%
plt.plot(daily_df['Date'], daily_df['Price'], label='Daily')
plt.plot(monthly_df['Month'], monthly_df['Price'], label= 'Monthly')
plt.title('Daily Natural Gas Prices')
plt.xlabel('Date')
plt.ylabel('Price ($)')
plt.xticks(daily_df['Date'][::365],rotation=45)
plt.legend()
plt.show()

# %%
plt.plot()
